# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import warnings
from sklearn.model_selection import GridSearchCV
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image  
import pickle

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('winequality_red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe().transpose()
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
x = df.drop(columns='quality')
y = df['quality']

# %%
ss = StandardScaler()
ss_x = ss.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(ss_x,y,test_size = 0.30, random_state= 355)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
y_predict = dtc.predict(x_test)
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))
# Out:
# 0.65
# [[  0   0   1   1   0   0]
#  [  0   4   4   7   2   0]
#  [  0   6 154  38  14   1]
#  [  1   6  50 115  17   3]
#  [  0   1   6   3  39   5]
#  [  0   0   0   0   2   0]]
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.24      0.24      0.24        17
#            5       0.72      0.72      0.72       213
#            6       0.70      0.60      0.65       192
#            7       0.53      0.72      0.61        54
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.65       480
#    macro avg       0.36      0.38      0.37       480
# weighted avg       0.67      0.65      0.65       480

# %%
data = export_graphviz(dtc,feature_names = x.columns,rounded=True,filled=True)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('wine_tree.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-60-a4a277ed03fc> in <module>
#       1 data = export_graphviz(dtc,feature_names = x.columns,rounded=True,filled=True)
#       2 graph = pydotplus.graph_from_dot_data(data)
# ----> 3 graph.write_png('wine_tree.png')
#       4 Image(graph.create_png())
#
# ~\Anaconda3\lib\site-packages\pydotplus\graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# ~\Anaconda3\lib\site-packages\pydotplus\graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# ...

# %%
dtc.predict([[7.4,0.70,0.0,1.9,0.076,11.0,34.0,0.9978,3.51,0.56,9.4]])
# Out:
# array([5], dtype=int64)

# %%
fname = "wine_quality.sav"
pickle.dump(dtc,open(fname,'wb'))
